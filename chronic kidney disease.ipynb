# %%
import numpy as np
import pandas as pd

# %% [raw]
# #loading the data set

# %%
data=pd.read_csv(r"C:\Users\JahnaviP\Downloads\chronickidneydisease.csv")

# %%
data
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# ...

# %%
df1=pd.read_csv(r"C:\Users\JahnaviP\Downloads\chronickidneydisease.csv")

# %%
df1
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# ...

# %%
data.isnull().any()
# Out:
# id                False
# age                True
# bp                 True
# sg                 True
# al                 True
# su                 True
# rbc                True
# pc                 True
# pcc                True
# ba                 True
# bgr                True
# bu                 True
# sc                 True
# sod                True
# pot                True
# hemo               True
# pcv                True
# wc                 True
# rc                 True
# htn                True
# dm                 True
# cad                True
# appet              True
# pe                 True
# ane                True
# classification    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
# id                400 non-null int64
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# rbc               248 non-null object
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# sod               313 non-null float64
# pot               312 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# wc                295 non-null object
# rc                270 non-null object
# htn               398 non-null object
# dm                398 non-null object
# ...

# %%
type(data.pcv)
# Out:
# pandas.core.series.Series

# %%
data.count()
# Out:
# id                400
# age               391
# bp                388
# sg                353
# al                354
# su                351
# rbc               248
# pc                335
# pcc               396
# ba                396
# bgr               356
# bu                381
# sc                383
# sod               313
# pot               312
# hemo              348
# pcv               330
# wc                295
# rc                270
# htn               398
# dm                398
# cad               398
# appet             399
# pe                399
# ane               399
# classification    400
# dtype: int64

# %%
df=data.rename(columns={'classification':'cla'})

# %%
data.isnull().any()
# Out:
# id                False
# age                True
# bp                 True
# sg                 True
# al                 True
# su                 True
# rbc                True
# pc                 True
# pcc                True
# ba                 True
# bgr                True
# bu                 True
# sc                 True
# sod                True
# pot                True
# hemo               True
# pcv                True
# wc                 True
# rc                 True
# htn                True
# dm                 True
# cad                True
# appet              True
# pe                 True
# ane                True
# classification    False
# dtype: bool

# %%
data.age.fillna(data.age.mean(),inplace=True)

# %%
data.head(1)
# Out:
#    id   age    bp    sg   al   su  rbc      pc         pcc          ba  ...  \
# 0   0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  ...
#
#    pcv    wc   rc  htn   dm  cad appet  pe ane classification
# 0   44  7800  5.2  yes  yes   no  good  no  no            ckd
#
# [1 rows x 26 columns]

# %%
data.age.mean()
# Out:
# 51.4833759590793

# %%
data.isnull().any()
# Out:
# id                False
# age               False
# bp                 True
# sg                 True
# al                 True
# su                 True
# rbc                True
# pc                 True
# pcc                True
# ba                 True
# bgr                True
# bu                 True
# sc                 True
# sod                True
# pot                True
# hemo               True
# pcv                True
# wc                 True
# rc                 True
# htn                True
# dm                 True
# cad                True
# appet              True
# pe                 True
# ane                True
# classification    False
# dtype: bool

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  400.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   16.974966   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   54.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.000000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
data.drop(data.loc[:,'hemo':'classification'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 15 columns):
# id     400 non-null int64
# age    400 non-null float64
# bp     388 non-null float64
# sg     353 non-null float64
# al     354 non-null float64
# su     351 non-null float64
# rbc    248 non-null object
# pc     335 non-null object
# pcc    396 non-null object
# ba     396 non-null object
# bgr    356 non-null float64
# bu     381 non-null float64
# sc     383 non-null float64
# sod    313 non-null float64
# pot    312 non-null float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 47.0+ KB

# %%
data.drop(data.loc[:,'rbc':'ba'],axis=1,inplace=True)

# %%
data
# Out:
#       id   age     bp     sg   al   su    bgr     bu    sc    sod  pot
# 0      0  48.0   80.0  1.020  1.0  0.0  121.0   36.0   1.2    NaN  NaN
# 1      1   7.0   50.0  1.020  4.0  0.0    NaN   18.0   0.8    NaN  NaN
# 2      2  62.0   80.0  1.010  2.0  3.0  423.0   53.0   1.8    NaN  NaN
# 3      3  48.0   70.0  1.005  4.0  0.0  117.0   56.0   3.8  111.0  2.5
# 4      4  51.0   80.0  1.010  2.0  0.0  106.0   26.0   1.4    NaN  NaN
# 5      5  60.0   90.0  1.015  3.0  0.0   74.0   25.0   1.1  142.0  3.2
# 6      6  68.0   70.0  1.010  0.0  0.0  100.0   54.0  24.0  104.0  4.0
# 7      7  24.0    NaN  1.015  2.0  4.0  410.0   31.0   1.1    NaN  NaN
# 8      8  52.0  100.0  1.015  3.0  0.0  138.0   60.0   1.9    NaN  NaN
# 9      9  53.0   90.0  1.020  2.0  0.0   70.0  107.0   7.2  114.0  3.7
# 10    10  50.0   60.0  1.010  2.0  4.0  490.0   55.0   4.0    NaN  NaN
# 11    11  63.0   70.0  1.010  3.0  0.0  380.0   60.0   2.7  131.0  4.2
# ...

# %%
data.head(1)
# Out:
#    id   age    bp    sg   al   su    bgr    bu   sc  sod  pot
# 0   0  48.0  80.0  1.02  1.0  0.0  121.0  36.0  1.2  NaN  NaN

# %%
data.isnull().any()
# Out:
# id     False
# age    False
# bp      True
# sg      True
# al      True
# su      True
# bgr     True
# bu      True
# sc      True
# sod     True
# pot     True
# dtype: bool

# %%
data.bp.fillna(data.bp.mean(),inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
# id     400 non-null int64
# age    400 non-null float64
# bp     400 non-null float64
# sg     353 non-null float64
# al     354 non-null float64
# su     351 non-null float64
# bgr    356 non-null float64
# bu     381 non-null float64
# sc     383 non-null float64
# sod    313 non-null float64
# pot    312 non-null float64
# dtypes: float64(10), int64(1)
# memory usage: 34.5 KB

# %%
data.sg.fillna(data.sg.mean(),inplace=True)
data.al.fillna(data.al.mean(),inplace=True)
data.su.fillna(data.su.mean(),inplace=True)
data.bgr.fillna(data.bgr.mean(),inplace=True)
data.bu.fillna(data.bu.mean(),inplace=True)
data.sc.fillna(data.sc.mean(),inplace=True)
data.sod.fillna(data.sod.mean(),inplace=True)
data.pot.fillna(data.pot.mean(),inplace=True)

# %%
data
# Out:
#       id   age          bp        sg        al        su         bgr  \
# 0      0  48.0   80.000000  1.020000  1.000000  0.000000  121.000000
# 1      1   7.0   50.000000  1.020000  4.000000  0.000000  148.036517
# 2      2  62.0   80.000000  1.010000  2.000000  3.000000  423.000000
# 3      3  48.0   70.000000  1.005000  4.000000  0.000000  117.000000
# 4      4  51.0   80.000000  1.010000  2.000000  0.000000  106.000000
# 5      5  60.0   90.000000  1.015000  3.000000  0.000000   74.000000
# 6      6  68.0   70.000000  1.010000  0.000000  0.000000  100.000000
# 7      7  24.0   76.469072  1.015000  2.000000  4.000000  410.000000
# 8      8  52.0  100.000000  1.015000  3.000000  0.000000  138.000000
# 9      9  53.0   90.000000  1.020000  2.000000  0.000000   70.000000
# 10    10  50.0   60.000000  1.010000  2.000000  4.000000  490.000000
# 11    11  63.0   70.000000  1.010000  3.000000  0.000000  380.000000
# 12    12  68.0   70.000000  1.015000  3.000000  1.000000  208.000000
# ...

# %%
data.isnull().any()
# Out:
# id     False
# age    False
# bp     False
# sg     False
# al     False
# su     False
# bgr    False
# bu     False
# sc     False
# sod    False
# pot    False
# dtype: bool

# %%
from sklearn.model_selection import train_test_split
data_train,data_test=train_test_split(data,test_size=0.4,random_state=0)

# %%
data_test
# Out:
#       id        age          bp        sg        al        su         bgr  \
# 132  132  50.000000   76.469072  1.017408  1.016949  0.450142  219.000000
# 309  309  51.000000   60.000000  1.020000  0.000000  0.000000  129.000000
# 341  341  63.000000   70.000000  1.025000  0.000000  0.000000  130.000000
# 196  196  49.000000  100.000000  1.010000  3.000000  0.000000  129.000000
# 246  246  48.000000  110.000000  1.015000  3.000000  0.000000  106.000000
# 60    60  67.000000   90.000000  1.020000  1.000000  0.000000  141.000000
# 155  155  50.000000   70.000000  1.020000  3.000000  0.000000  123.000000
# 261  261  49.000000   80.000000  1.020000  0.000000  0.000000  122.000000
# 141  141  67.000000   70.000000  1.010000  1.000000  0.000000  148.036517
# 214  214  68.000000   80.000000  1.015000  0.000000  0.000000  171.000000
# 37    37  72.000000   80.000000  1.017408  1.016949  0.450142  137.000000
# 134  134  47.000000  100.000000  1.010000  1.016949  0.450142  122.000000
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot'], dtype='object')

# %%
df
# Out:
#       id   age          bp        sg        al        su         bgr  \
# 0      0  48.0   80.000000  1.020000  1.000000  0.000000  121.000000
# 1      1   7.0   50.000000  1.020000  4.000000  0.000000  148.036517
# 2      2  62.0   80.000000  1.010000  2.000000  3.000000  423.000000
# 3      3  48.0   70.000000  1.005000  4.000000  0.000000  117.000000
# 4      4  51.0   80.000000  1.010000  2.000000  0.000000  106.000000
# 5      5  60.0   90.000000  1.015000  3.000000  0.000000   74.000000
# 6      6  68.0   70.000000  1.010000  0.000000  0.000000  100.000000
# 7      7  24.0   76.469072  1.015000  2.000000  4.000000  410.000000
# 8      8  52.0  100.000000  1.015000  3.000000  0.000000  138.000000
# 9      9  53.0   90.000000  1.020000  2.000000  0.000000   70.000000
# 10    10  50.0   60.000000  1.010000  2.000000  4.000000  490.000000
# 11    11  63.0   70.000000  1.010000  3.000000  0.000000  380.000000
# 12    12  68.0   70.000000  1.015000  3.000000  1.000000  208.000000
# ...

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   16.974966   13.476298    0.005369    1.272318    1.029487
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.015000    0.000000    0.000000
# 50%    199.500000   54.000000   78.234536    1.017408    1.000000    0.000000
# 75%    299.250000   64.000000   80.000000    1.020000    2.000000    0.450142
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot
# count  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244
# std     74.782634   49.285887    5.617490    9.204273    2.819783
# ...

# %%
df.corr()

# %%
df.dtypes.index.values
# Out:
# array(['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod',
#        'pot'], dtype=object)

# %%
df1
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# ...
